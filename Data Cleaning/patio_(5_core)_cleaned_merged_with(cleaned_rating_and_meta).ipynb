# %%
import pandas as pd 
import numpy as np 
import seaborn as sb 
import matplotlib.pyplot as plt 
import warnings 
warnings.filterwarnings("ignore")

# %%
myfile1 = "C:/Users/anime/Downloads/Patio_Lawn_and_Garden_5(core).csv"

# %%
Patio_Lawn_and_Garden_5 = pd.read_csv(myfile1)#, sep=',', names=header_info,header=None)

# %%
Patio_Lawn_and_Garden_5.head()
# Out:
#    overall vote  verified   reviewTime      reviewerID        asin  \
# 0      5.0    2      True  12 11, 2011   AUVPE2KEXBJVT  9539723809
# 1      5.0  NaN      True  07 30, 2011  A2F6GES1MBOFXS  9539723809
# 2      5.0  NaN      True   05 4, 2016  A1SDVD3SZI1BAK  9539723809
# 3      5.0  NaN      True   11 2, 2015  A1ZQJ3KCSLUPR3  9539723809
# 4      5.0  NaN      True   09 1, 2015   ANU8FBZM618M3  9539723809
#
#          reviewerName                                         reviewText  \
# 0         T. E. Kainz  I don't spend a lot on my flags because they r...
# 1         BluesJamJim  Super fast processing and shipping, if you are...
# 2  Gabriel M Martinez  Great product.  I would recommend this product...
# 3       RAJ THE FLASH            GREAT PRICE I LOVE MY STATE AND COUNTRY
# 4      James R. Mills                    Great display flag for the den.
#
#                       summary  unixReviewTime style image
# 0  Good quality for the price      1323561600   NaN   NaN
# ...

# %%
Patio_Lawn_and_Garden_5.shape
# Out:
# (798415, 12)

# %%
Patio_Lawn_and_Garden_5 = Patio_Lawn_and_Garden_5[["overall","verified","reviewerID","asin","reviewText"]]

# %%
Patio_Lawn_and_Garden_5.shape
# Out:
# (798415, 5)

# %%
Patio_Lawn_and_Garden_5.head()
# Out:
#    overall  verified      reviewerID        asin  \
# 0      5.0      True   AUVPE2KEXBJVT  9539723809
# 1      5.0      True  A2F6GES1MBOFXS  9539723809
# 2      5.0      True  A1SDVD3SZI1BAK  9539723809
# 3      5.0      True  A1ZQJ3KCSLUPR3  9539723809
# 4      5.0      True   ANU8FBZM618M3  9539723809
#
#                                           reviewText
# 0  I don't spend a lot on my flags because they r...
# 1  Super fast processing and shipping, if you are...
# 2  Great product.  I would recommend this product...
# 3            GREAT PRICE I LOVE MY STATE AND COUNTRY
# 4                    Great display flag for the den.

# %%
Patio_Lawn_and_Garden_5.isnull().sum()
# Out:
# overall         0
# verified        0
# reviewerID      0
# asin            0
# reviewText    186
# dtype: int64

# %%
 Patio_Lawn_and_Garden_5.dropna(inplace = True)

# %%
Patio_Lawn_and_Garden_5.shape
# Out:
# (798229, 5)

# %%
Patio_Lawn_and_Garden_5.isnull().sum()
# Out:
# overall       0
# verified      0
# reviewerID    0
# asin          0
# reviewText    0
# dtype: int64

# %%
Patio_Lawn_and_Garden_5['overall'].value_counts()
# Out:
# 5.0    533459
# 4.0    123368
# 3.0     57468
# 1.0     51545
# 2.0     32389
# Name: overall, dtype: int64

# %%
Patio_Lawn_and_Garden_5['verified'].value_counts()
# Out:
# True     728296
# False     69933
# Name: verified, dtype: int64

# %%
Patio_Lawn_and_Garden_5['reviewerID'].value_counts()
# Out:
# A100WO06OQR8BQ    227
# A2TM0K7HUH7SLC    190
# A1JZFGZEZVWQPY    132
# A2NOQ59T4NM0N3    125
# AC61U16AJQ8X7     115
#                  ...
# AUDISUXI4CGW4       2
# A1G7EMHZ3RNA3T      1
# A4HET7OXYLFQT       1
# AMAV2M2QTAEO7       1
# AK1A6OK0AFBIT       1
# Name: reviewerID, Length: 103426, dtype: int64

# %%
Patio_Lawn_and_Garden_5['asin'].value_counts()
# Out:
# B0012QLVRM    2596
# B000WEKLTE    1718
# B00004R9VV    1481
# B000E28UQU    1470
# B00104WRCY    1432
#               ...
# B001047KXA       1
# B000NY9KCM       1
# B0010VL2Q4       1
# B001111M68       1
# B0014G2W1E       1
# Name: asin, Length: 32918, dtype: int64

# %%
Patio_Lawn_and_Garden_5['reviewText'].value_counts()
# Out:
# great                                                                                                                                                                                                                                                           2829
# good                                                                                                                                                                                                                                                            2628
# Great                                                                                                                                                                                                                                                           2048
# ...

# %%
lst_reviewText=[]
for i in Patio_Lawn_and_Garden_5['reviewText']:
    lst_reviewText.append(i)
set(lst_reviewText)
# Out:
# {'We have a small farm and out flagpole is next to a light pole.  Flag was of excellent quality and we fly it proudly.',
#  'Works very well.  The only negative aspect is that you have to set it the first time at the time  you want the water to turn on.  After that, it turns on at that time every one, two, or three days, whichever you choose.  Works very well.',
#  'They fit so we see how long they last',
#  'Like the item but the dekivery left alot of issues.',
#  'It is OK.',
# ...

# %%
Patio_Lawn_and_Garden_5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 798229 entries, 0 to 798414
# Data columns (total 5 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   overall     798229 non-null  float64
#  1   verified    798229 non-null  bool
#  2   reviewerID  798229 non-null  object
#  3   asin        798229 non-null  object
#  4   reviewText  798229 non-null  object
# dtypes: bool(1), float64(1), object(3)
# memory usage: 31.2+ MB

# %%
Patio_Lawn_and_Garden_5.rename(columns={'asin':'product_id'},inplace=True)

# %%
Patio_Lawn_and_Garden_5.rename(columns={'overall':'rating'},inplace=True)

# %%
Patio_Lawn_and_Garden_5.rename(columns={'reviewerID':'Reviewer_id'},inplace=True)

# %%
Patio_Lawn_and_Garden_5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 798229 entries, 0 to 798414
# Data columns (total 5 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   rating       798229 non-null  float64
#  1   verified     798229 non-null  bool
#  2   Reviewer_id  798229 non-null  object
#  3   product_id   798229 non-null  object
#  4   reviewText   798229 non-null  object
# dtypes: bool(1), float64(1), object(3)
# memory usage: 31.2+ MB

# %%
Patio_Lawn_and_Garden_5['reviewText']
# Out:
# 0         I don't spend a lot on my flags because they r...
# 1         Super fast processing and shipping, if you are...
# 2         Great product.  I would recommend this product...
# 3                   GREAT PRICE I LOVE MY STATE AND COUNTRY
# 4                           Great display flag for the den.
#                                 ...
# 798410     Great product at a great price and fast shipping
# 798411    Liked the cover.  Covers well and should last ...
# 798412    This is a nice quality grilling table where yo...
# 798413    Pulley was shipped as described. Still have th...
# 798414             Good replacement for a craftsman 42 deck
# Name: reviewText, Length: 798229, dtype: object

# %%
patio  = pd.read_csv('patio_meta_ratingsonly_merged_and_cleaned.csv')

# %%
patio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5197701 entries, 0 to 5197700
# Data columns (total 8 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   title        object
#  1   brand        object
#  2   main_cat     object
#  3   price        float64
#  4   product_id   object
#  5   Reviewer_id  object
#  6   rating       float64
#  7   date_time    int64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 317.2+ MB

# %%
patio.shape
# Out:
# (5197701, 8)

# %%
patio_core_merged_rating_csv=pd.merge(patio,Patio_Lawn_and_Garden_5,on=('product_id',"Reviewer_id","rating"),how='inner')

# %%
patio_core_merged_rating_csv.head()
# Out:
#                                   title      brand     main_cat      price  \
# 0  Colorado US State Flag: 3x5foot poly  3x5fFlags  Amazon Home  52.730167
# 1  Colorado US State Flag: 3x5foot poly  3x5fFlags  Amazon Home  52.730167
# 2  Colorado US State Flag: 3x5foot poly  3x5fFlags  Amazon Home  52.730167
# 3  Colorado US State Flag: 3x5foot poly  3x5fFlags  Amazon Home  52.730167
# 4  Colorado US State Flag: 3x5foot poly  3x5fFlags  Amazon Home  52.730167
#
#    product_id     Reviewer_id  rating   date_time  verified  \
# 0  9539723809   AUVPE2KEXBJVT     5.0  1323561600      True
# 1  9539723809  A2F6GES1MBOFXS     5.0  1311984000      True
# 2  9539723809  A1SDVD3SZI1BAK     5.0  1462320000      True
# 3  9539723809  A1ZQJ3KCSLUPR3     5.0  1446422400      True
# 4  9539723809   ANU8FBZM618M3     5.0  1441065600      True
#
#                                           reviewText
# 0  I don't spend a lot on my flags because they r...
# ...

# %%
patio_core_merged_rating_csv.isnull().sum()
# Out:
# title          0
# brand          0
# main_cat       0
# price          0
# product_id     0
# Reviewer_id    0
# rating         0
# date_time      0
# verified       0
# reviewText     0
# dtype: int64

# %%
# importing the datetime package  
import datetime  
  
# given epoch time  
epoch_time = 1391212800  
  
# using the datetime.fromtimestamp() function  
date_time = datetime.datetime.fromtimestamp( epoch_time )  
  
# printing the value  
print("Given epoch time:", epoch_time)  
print("Converted Datetime:", date_time )
# Out:
# Given epoch time: 1391212800
# Converted Datetime: 2014-02-01 05:30:00

# %%
def date_time(epoch_time):
    date_time = datetime.datetime.fromtimestamp( epoch_time )
    return date_time

# %%
patio_core_merged_rating_csv['date_time'] = patio_core_merged_rating_csv['date_time'].apply(date_time)

# %%
patio_core_merged_rating_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 932665 entries, 0 to 932664
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   title        932665 non-null  object
#  1   brand        932665 non-null  object
#  2   main_cat     932665 non-null  object
#  3   price        932665 non-null  float64
#  4   product_id   932665 non-null  object
#  5   Reviewer_id  932665 non-null  object
#  6   rating       932665 non-null  float64
#  7   date_time    932665 non-null  datetime64[ns]
#  8   verified     932665 non-null  bool
#  9   reviewText   932665 non-null  object
# dtypes: bool(1), datetime64[ns](1), float64(2), object(6)
# memory usage: 72.0+ MB

# %%
 patio_core_merged_rating_csv['DATE'] = pd.to_datetime(patio_core_merged_rating_csv['date_time']).dt.date

# %%
patio_core_merged_rating_csv.drop(columns=['date_time'],inplace = True)

# %%
patio_core_merged_rating_csv['DATE']=pd.to_datetime(patio_core_merged_rating_csv['DATE'])

# %%
patio_core_merged_rating_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 932665 entries, 0 to 932664
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   title        932665 non-null  object
#  1   brand        932665 non-null  object
#  2   main_cat     932665 non-null  object
#  3   price        932665 non-null  float64
#  4   product_id   932665 non-null  object
#  5   Reviewer_id  932665 non-null  object
#  6   rating       932665 non-null  float64
#  7   verified     932665 non-null  bool
#  8   reviewText   932665 non-null  object
#  9   DATE         932665 non-null  datetime64[ns]
# dtypes: bool(1), datetime64[ns](1), float64(2), object(6)
# memory usage: 72.0+ MB

# %%
patio_core_merged_rating_csv.head()
# Out:
#                                   title      brand     main_cat      price  \
# 0  Colorado US State Flag: 3x5foot poly  3x5fFlags  Amazon Home  52.730167
# 1  Colorado US State Flag: 3x5foot poly  3x5fFlags  Amazon Home  52.730167
# 2  Colorado US State Flag: 3x5foot poly  3x5fFlags  Amazon Home  52.730167
# 3  Colorado US State Flag: 3x5foot poly  3x5fFlags  Amazon Home  52.730167
# 4  Colorado US State Flag: 3x5foot poly  3x5fFlags  Amazon Home  52.730167
#
#    product_id     Reviewer_id  rating  verified  \
# 0  9539723809   AUVPE2KEXBJVT     5.0      True
# 1  9539723809  A2F6GES1MBOFXS     5.0      True
# 2  9539723809  A1SDVD3SZI1BAK     5.0      True
# 3  9539723809  A1ZQJ3KCSLUPR3     5.0      True
# 4  9539723809   ANU8FBZM618M3     5.0      True
#
#                                           reviewText       DATE
# 0  I don't spend a lot on my flags because they r... 2011-12-11
# 1  Super fast processing and shipping, if you are... 2011-07-30
# ...

# %%
patio_core_merged_rating_csv['brand'].unique()[:50]
# Out:
# array(['3x5fFlags', 'Bully Tools', 'Estwing', 'Taylor Precision',
#        'Link Handles', 'Earthway', 'Fiskars', 'Gilmour', 'Headwind',
#        'Nelson', 'Seymour', 'The AMES Companies, Inc', 'Solo, Inc.',
#        'Sprayco', 'Teknor Apex', 'Heath Outdoor Products', 'Ross',
#        'Red Barn', 'Agri-Fab', 'Taylor Precision Products',
#        'Beckett Corporation', 'Dalen', 'HD Hudson',
#        'Cherry Valley Feeders', 'Rain Bird', 'Apex',
#        'Chapin International', 'Raindrip', 'Dover Parkersburg',
#        'Safer Brand', 'Weed Eater', 'Fulton', "Gardener's Blue Ribbon",
#        'Spectracide', 'Universal Forest', 'Intex', 'BLACK+DECKER', 'OXO',
#        'Ryobi', 'Black & Decker', 'American Lawn Mower Company',
#        'Trimmer Plus', 'Andrews', 'Flowtron', 'Arnold', 'Grass Gator',
#        'Corona', 'Easy Gardener', 'Garden Weasel', 'Corona Clipper'],
#       dtype=object)

# %%
patio_core_merged_rating_csv.shape
# Out:
# (932665, 10)

# %%
patio_core_merged_rating_csv.to_csv("PATIO_COMPLETELY_CLEAN_FULLY_MERGED_RDY_FOR_MDLLING",index=False)
