# %%
import pandas as pd 
import numpy as np 
import seaborn as sb 
import matplotlib.pyplot as plt 
import warnings 
warnings.filterwarnings("ignore")

# %%
myfile1 = "C:/Users/anime/Downloads/Tools_and_Home_Improvement_5(core).csv"

# %%
Tools_and_Home_Improvement_5 = pd.read_csv(myfile1)#, sep=',', names=header_info,header=None)

# %%
Tools_and_Home_Improvement_5.head()
# Out:
#    overall  verified   reviewTime      reviewerID        asin  \
# 0      5.0      True  01 28, 2018   AL19QO4XLBQPU  0982085028
# 1      5.0      True  11 30, 2017  A1I7CVB7X3T81E  0982085028
# 2      5.0      True  09 12, 2017  A1AQXO4P5U674E  0982085028
# 3      4.0      True  07 19, 2017   AIRV678P7C4NK  0982085028
# 4      1.0      True  05 25, 2017  A22I5QDNTNECDW  0982085028
#
#                                          style   reviewerName  \
# 0  {'Style:': ' 1) IR30 POU (30A/3.4kW/110v)'}  J. Mollenkamp
# 1   {'Style:': ' 3) IR260 POU (30A/6kW/220v)'}         warfam
# 2                       {'Style:': ' Style64'}       gbieber2
# 3                                          NaN  Justin Banner
# 4   {'Style:': ' 3) IR260 POU (30A/6kW/220v)'}     daveparker
#
#                                           reviewText  \
# 0             returned, decided against this product
# 1  Awesome heater for the electrical requirements...
# ...

# %%
Tools_and_Home_Improvement_5.shape
# Out:
# (2070831, 12)

# %%
Tools_and_Home_Improvement_5 = Tools_and_Home_Improvement_5[["overall","verified","reviewerID","asin","reviewText"]]

# %%
Tools_and_Home_Improvement_5.shape
# Out:
# (2070831, 5)

# %%
Tools_and_Home_Improvement_5.isnull().sum()
# Out:
# overall         0
# verified        0
# reviewerID      0
# asin            0
# reviewText    522
# dtype: int64

# %%
Tools_and_Home_Improvement_5.dropna(inplace = True)

# %%
Tools_and_Home_Improvement_5.shape
# Out:
# (2070309, 5)

# %%
Tools_and_Home_Improvement_5['overall'].value_counts()
# Out:
# 5.0    1424804
# 4.0     335321
# 3.0     139446
# 1.0      97831
# 2.0      72907
# Name: overall, dtype: int64

# %%
Tools_and_Home_Improvement_5['verified'].value_counts()
# Out:
# True     1902423
# False     167886
# Name: verified, dtype: int64

# %%
Tools_and_Home_Improvement_5['reviewerID'].value_counts()
# Out:
# A1JZFGZEZVWQPY    272
# A3L1VJMHFWONCB    266
# A1H2WJSALF3E9U    255
# A2UEH0U5CV3053    243
# A365PBEOWM7EI7    219
#                  ...
# A3DHCIDXXT0GO8      1
# A2MJG1HL0X64TW      1
# AJECPCOLT4S8Y       1
# A2X7PMXJ4X11JY      1
# A4HET7OXYLFQT       1
# Name: reviewerID, Length: 240796, dtype: int64

# %%
Tools_and_Home_Improvement_5['asin'].value_counts()
# Out:
# B0015UC17E    3871
# B0011UIPIW    3533
# B0014KMDZ0    3104
# B002JWSNIS    2919
# B000X05G1A    2898
#               ...
# B000ZOUB64       1
# B0017U7M3K       1
# B0011YJHQ2       1
# B000ZM312C       1
# B001280XRO       1
# Name: asin, Length: 73649, dtype: int64

# %%
Tools_and_Home_Improvement_5['reviewText'].value_counts()
# Out:
# good                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 7
# ...

# %%
lst_reviewText=[]
for i in Tools_and_Home_Improvement_5['reviewText']:
    lst_reviewText.append(i)
set(lst_reviewText)
# Out:
# {"Good value for flashlights that you can give away or stash in different bags or places around your house.  All 5 worked right out of the box.  The light is bright enough to see well inside and even short distances outside.  I prefer the low setting because the battery life isn't all that great with these.  I know that, so I bring extra batteries if I am traveling.  That being said, I would take a different flashlight if I was doing more hardcore camping or exploring.",
#  'High quality.  You can use it to open your Amazon boxes.',
# ...

# %%
Tools_and_Home_Improvement_5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2070309 entries, 0 to 2070830
# Data columns (total 5 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   overall     float64
#  1   verified    bool
#  2   reviewerID  object
#  3   asin        object
#  4   reviewText  object
# dtypes: bool(1), float64(1), object(3)
# memory usage: 81.0+ MB

# %%
Tools_and_Home_Improvement_5.rename(columns={'asin':'product_id'},inplace=True)

# %%
Tools_and_Home_Improvement_5.rename(columns={'overall':'rating'},inplace=True)

# %%
Tools_and_Home_Improvement_5.rename(columns={'reviewerID':'Reviewer_id'},inplace=True)

# %%
Tools_and_Home_Improvement_5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2070309 entries, 0 to 2070830
# Data columns (total 5 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   rating       float64
#  1   verified     bool
#  2   Reviewer_id  object
#  3   product_id   object
#  4   reviewText   object
# dtypes: bool(1), float64(1), object(3)
# memory usage: 81.0+ MB

# %%
Tools_and_Home_Improvement_5.shape
# Out:
# (2070309, 5)

# %%
# tools.to_csv('tools_meta_ratingsonly_merged_and_cleaned.csv',index=False)

# %%
tools = pd.read_csv('tools_meta_ratingsonly_merged_and_cleaned.csv')

# %%
tools.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8537571 entries, 0 to 8537570
# Data columns (total 8 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   title        object
#  1   brand        object
#  2   main_cat     object
#  3   price        float64
#  4   product_id   object
#  5   Reviewer_id  object
#  6   rating       float64
#  7   date_time    int64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 521.1+ MB

# %%
tools.shape
# Out:
# (8537571, 8)

# %%
tools_core_merged_rating_csv=pd.merge(tools,Tools_and_Home_Improvement_5,on=('product_id',"Reviewer_id","rating"),how='inner')

# %%
tools_core_merged_rating_csv
# Out:
#                                                      title       brand  \
# 0        Breeding Organic Vegetables: A Step-by-Step Gu...    SioGreen
# 1        Breeding Organic Vegetables: A Step-by-Step Gu...    SioGreen
# 2        Breeding Organic Vegetables: A Step-by-Step Gu...    SioGreen
# 3        Breeding Organic Vegetables: A Step-by-Step Gu...    SioGreen
# 4        Breeding Organic Vegetables: A Step-by-Step Gu...    SioGreen
# ...                                                    ...         ...
# 2267340      BRASSCRAFT BC00400 Zip-it Drain Cleaning Tool  BrassCraft
# 2267341      BRASSCRAFT BC00400 Zip-it Drain Cleaning Tool  BrassCraft
# 2267342      BRASSCRAFT BC00400 Zip-it Drain Cleaning Tool  BrassCraft
# 2267343      BRASSCRAFT BC00400 Zip-it Drain Cleaning Tool  BrassCraft
# 2267344      BRASSCRAFT BC00400 Zip-it Drain Cleaning Tool  BrassCraft
#
#                          main_cat      price  product_id     Reviewer_id  \
# ...

# %%
tools_core_merged_rating_csv.isnull().sum()
# Out:
# title          0
# brand          0
# main_cat       0
# price          0
# product_id     0
# Reviewer_id    0
# rating         0
# date_time      0
# verified       0
# reviewText     0
# dtype: int64

# %%
tools_core_merged_rating_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2267345 entries, 0 to 2267344
# Data columns (total 10 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   title        object
#  1   brand        object
#  2   main_cat     object
#  3   price        float64
#  4   product_id   object
#  5   Reviewer_id  object
#  6   rating       float64
#  7   date_time    int64
#  8   verified     bool
#  9   reviewText   object
# dtypes: bool(1), float64(2), int64(1), object(6)
# memory usage: 175.1+ MB

# %%
# importing the datetime package  
import datetime  
  
# given epoch time  
epoch_time = 1391212800  
  
# using the datetime.fromtimestamp() function  
date_time = datetime.datetime.fromtimestamp( epoch_time )  
  
# printing the value  
print("Given epoch time:", epoch_time)  
print("Converted Datetime:", date_time )
# Out:
# Given epoch time: 1391212800
# Converted Datetime: 2014-02-01 05:30:00

# %%
def date_time(epoch_time):
    date_time = datetime.datetime.fromtimestamp( epoch_time )
    return date_time

# %%
tools_core_merged_rating_csv['date_time'] = tools_core_merged_rating_csv['date_time'].apply(date_time)

# %%
tools_core_merged_rating_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2267345 entries, 0 to 2267344
# Data columns (total 10 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   title        object
#  1   brand        object
#  2   main_cat     object
#  3   price        float64
#  4   product_id   object
#  5   Reviewer_id  object
#  6   rating       float64
#  7   date_time    datetime64[ns]
#  8   verified     bool
#  9   reviewText   object
# dtypes: bool(1), datetime64[ns](1), float64(2), object(6)
# memory usage: 175.1+ MB

# %%
tools_core_merged_rating_csv['DATE'] = pd.to_datetime(tools_core_merged_rating_csv['date_time']).dt.date

# %%
tools_core_merged_rating_csv.drop(columns=['date_time'],inplace = True)

# %%
tools_core_merged_rating_csv['DATE']=pd.to_datetime(tools_core_merged_rating_csv['DATE'])

# %%
tools_core_merged_rating_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2267345 entries, 0 to 2267344
# Data columns (total 10 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   title        object
#  1   brand        object
#  2   main_cat     object
#  3   price        float64
#  4   product_id   object
#  5   Reviewer_id  object
#  6   rating       float64
#  7   verified     bool
#  8   reviewText   object
#  9   DATE         datetime64[ns]
# dtypes: bool(1), datetime64[ns](1), float64(2), object(6)
# memory usage: 175.1+ MB

# %%
tools_core_merged_rating_csv.head()
# Out:
#                                                title     brand  \
# 0  Breeding Organic Vegetables: A Step-by-Step Gu...  SioGreen
# 1  Breeding Organic Vegetables: A Step-by-Step Gu...  SioGreen
# 2  Breeding Organic Vegetables: A Step-by-Step Gu...  SioGreen
# 3  Breeding Organic Vegetables: A Step-by-Step Gu...  SioGreen
# 4  Breeding Organic Vegetables: A Step-by-Step Gu...  SioGreen
#
#                    main_cat      price  product_id     Reviewer_id  rating  \
# 0  Tools & Home Improvement  45.902274  0982085028   AL19QO4XLBQPU     5.0
# 1  Tools & Home Improvement  45.902274  0982085028  A1I7CVB7X3T81E     5.0
# 2  Tools & Home Improvement  45.902274  0982085028  A1AQXO4P5U674E     5.0
# 3  Tools & Home Improvement  45.902274  0982085028   AIRV678P7C4NK     4.0
# 4  Tools & Home Improvement  45.902274  0982085028  A22I5QDNTNECDW     1.0
#
#    verified                                         reviewText       DATE
# ...

# %%
tools_core_merged_rating_csv.shape
# Out:
# (2267345, 10)

# %%
tools_core_merged_rating_csv.to_csv("TOOLS_COMPLETELY_CLEAN_FULLY_MERGED_RDY_FOR_MDLLING",index=False)
